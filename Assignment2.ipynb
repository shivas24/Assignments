# %%
1.What are the two values of the Boolean data type? How do you write them
True and False  
a =5 
bool(a==5) ..True

b =3
bool(b==3) .. True
bool(a !=5).. False
bool(b!=3)	.. False	
bool(a ==b) .. False
bool(a !=b)..True
	
2. What are the three different types of Boolean operators?
AND ,OR,NOT

3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate).
a =5 
b =3
a and b  …False
a or b..True
x= False
not x ..True
a>b and b<a ..True
a>b or b>a  ..True
a>b and b>a..False

4. What are the values of the following expressions?
(5 > 4) and (3 == 5)…False
not (5 > 4)  ..False
(5 > 4) or (3 == 5)…True
not ((5 > 4) or (3 == 5))….False
(True and True) and (True == False)….False
(not False) or (not True)..   True

5. What are the six comparison operators?
==    equal to
!=	notequalto
>	Greater Than
<	LessThan
>=	Greater Than equal to
<=	less than  or equal to

6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.
A=5…Here we are assigning value 5 to A using =
If A ==5..Here we are comparing value of A(i.e 5)  with numerical value 5

7. Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
elif spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

If block 
Elif Block
Else block

8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
spam = 0
if spam == 1:
  print('Hello')
elif spam ==2:
  print('Howdy')
else:
  print('Greetings')
  

9.If your programme is stuck in an endless loop, what keys you’ll press?
Ctrl + C    in command prompt as hard quit. We can use break keyword to  break the loop or passing a if condition or return in functions

10. How can you tell the difference between break and continue?
Break is a premature exit from the loop.
Foreg… 
for i in range(1,8):
    if (i ==5):
          break
    print(i)
Here the i ranges from upto 8, when the condition satisfies i.e. i becomes 5, break executes and come out from the loop. So the output will be 1,2,3,4  	

Continue will skip the current iteration of the given expression and continues to next iteration

for i in range(1,8):
    if (i ==5):
        continue
    print(i)
here when i equals to 5 skip that iteration and continues to next.so the value of 5 will not be printed and remaining will be printed . i.e. 1,2,3,4,6,7		



11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
In the above output will be same for all. The syntax is

Range(10)….print values from 0  by default start index to 9… 
for i in range(10):
  print(i)   #prints 0…9

range(0,10)…prints from specific range 0 to 10-1=9
for i in range(0,10):
  print(i)#prints 0 …9

for i in range(0,10,1):prints from range 0 to9 by step of 1
  print(i)#prints0…9 by increments of 1

for i in range(0,30,3):
  print(i) # prints 0 to 27 by incrementing 3
output will be 0,3,6,9,12…27

12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

for i in range(1,11):
  print(i)

i=1
while i <= 10:
  print(i)
  i +=1

or .

i=1
while i != 11:
  print(i)
  i +=1


13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

Def bacon():
	Print(“Hello World”)

Import spam
spam. bacon()


Or

From spam import bacon
Result	=	bacon()
Print(Result)
