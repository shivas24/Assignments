# %%
1. What exactly is []?
	Empty List

2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
Spam=[2,4,6,8,10]
Spam[2]=’hello’
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

3. What is the value of spam[int(int('3' * 2) / 11)]?
	Spam=[a,b,c,d]
	Spam[int(int(33)/11)]
	Spam[int(3)]=spam[3]=d

4. What is the value of spam[-1]?
	Spam[-1]=d

5. What is the value of spam[:2]?
	Spam[:2]=a,b
Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

6. What is the value of bacon.index('cat')?
	bacon=[3.14, 'cat', 11, 'cat', True]
	bacon.index(‘cat’)=1	

7. How does bacon.append(99) change the look of the list value in bacon?
	Bacon.append(99)
Bacon=[3.14, 'cat', 11, 'cat', True, 99]

8. How does bacon.remove('cat') change the look of the list in bacon?
	bacon=[3.14, 11, True,99]

9. What are the list concatenation and list replication operators?
	+ is list concatenation   * for list replication
L1=[1,2,3]    L2=[4,5,6]
Concatenation= L1+L2=[1,2,3,4,5,6]
Replication= L1*2=[1,2,3,1,2,3]

10. What is difference between the list methods append() and insert()?
Append()  inserts end of the list.
Insert() inserts at particular index
L1=[1,2,3]
L1.append(9)=[1,2,3,9]
L1.insert(1,9)=[1,9,2,3]

11. What are the two methods for removing items from a list?
L1=[1,9,2,3]
Remove(),pop()
L1.pop(2)=removes 3rd element=[1,9,3]  #Removes at particular index
L1.remove(9)=[1,2,3] #Removes specified value

12. Describe how list values and string values are identical.
	Lst1=[“hello”,1,2.4] lst2=[“Hi”,2,3.1]
	Str=”Hello”  str2=”Hi”
Both lists and string can be concatenated using  + sign
	Lst1+lst2=['hello', 1, 2.4, 'Hi', 2, 3.1]
	Str+str2=”HelloHi”
Both can be accessed using index and slicing
	Lst[1]=1 str[1]=e  Indexed
	Lst1[0:2]=hello,1   Str[0:2]=He
Both can be looped or iterated

13. What's the difference between tuples and lists?
Tuples are immutable and no duplicates
Lists are mutable and duplicates
Lis=[1,2,1,3]  can allow duplicates. Can add elements using lis.append(4)
Tup=(1,2,3)  no  duplicates  cant add. need to convert to lists using list() ,then add elements then convert to tuple using tuple() or (,)

14. How do you type a tuple value that only contains the integer 42?
Tup=(42,)

15. How do you get a list value's tuple form? How do you get a tuple value's list form?
Ls=[1,2,3]   to  tuple t=tuple(Ls)  … type(t).. tuple
Tup=(1,2,3)  list(Tup)…l=list(Tup)… type(l)..list

16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
Variable represents list and list both represents same memory location. whatever changes made in  variable can reflect in list also. 
Eg..lst=[1,2,3] 
 lst2=lst   
lst2.append(6) 
lst modified as [1,2,3,6]

17. How do you distinguish between copy.copy() and copy.deepcopy()?
Copy.copy() can not create any new object but reference the same object. so whatever changes made in anyone can reflect on both
We need to import copy library for this
Eg.. 
import copy
original_list = [[1, 2, 3], [4, 5, 6]]  #nested list
copy_copy = copy. copy(original_list)
original_list[0][0] = 99 #adding [0] index of [0]
print(copy_copy)  # Output= [[99, 2, 3], [4, 5, 6]]
print(original_list). # output=[[99,2,3],[4,5,6]


deepcopy function will not update or change original values. It creates new object. So whatever the chages made will be reflected to given object only. Not on both
import copy
original_list = [[1, 2, 3], [4, 5, 6]] #Nested list
deep_copy = copy.deepcopy(original_list)
original_list[0][0] = 99
print(deep_copy)  # Output = [[1, 2, 3], [4, 5, 6]]
print(original_list) #output = [[99,2,3],[4,5,6]]
