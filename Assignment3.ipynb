# %%
1. Why are functions advantageous to have in your programs?
	The basic advantage of functions is reusability of code. Instead of writing long codes we can made it modular .This can help to reduce code length finally saves memory and storage. It can help to run programs fastly. 

2. When does the code in a function run: when it's specified or when it's called?
Always a function runs when we call it any where in the program.

Def function()…which defines a function….
Eg.. def bacon():  is the syntax  of a function

Def  bacon():
	Print(“Hello”)
Bacon()	

Here we are calling above function bacon() at the bottom line
 
3. What statement creates a function?
Def function()…which defines a function….
Eg.. def bacon():  is the syntax  of a function

Def  bacon(): 
	Print(“Hello”)

4. What is the difference between a function and a function call?

To define a function we need to use def and function name with () any by passing a parameters in between parathesis or empty. Then colon(:). This is the format of a function. 

Def function()…which defines a function….
Eg.. def bacon():  is the syntax  of a function

Def  bacon():
	Print(“Hello”)

Bacon()     ….This is the function call	

5. How many global scopes are there in a Python program? How many local scopes?

The variables defined outside a function is called as global scope variable..  generally we use global keyword for this. If a variable defined inside a function is called as local variable. 

There are 3 types of variables
1.	Global variable
2.	Local variable…. Private variable
3.	Protected variables


6. What happens to variables in a local scope when the function call returns?

	We can not call a local variable from outside of a function. When we define a function variable inside a function that variable is local variable to that function by default. So when we call return that value we need to assign that value through the function parameter outside the function.
Eg..

def my_fun():
    local_var = 10
    print("Inside the function Value is:", local_var)
    return local_var  # Returns the local variable

return_value = my_fun()
print("Outside the function Value is:", return_value)

			
  
7. What is the concept of a return value? Is it possible to have a return value in an expression?
	
The main purpose of return value is what ever the code we have written is to be executed and we use return that value to outside the function for further use. Second in an expression we can have return value.

def my_fun(a,b):
    sum = a+b # here a=3 b=5
    print("SUM Inside function is::",sum)
    return sum  # Returns the local variable

return_value = my_fun(3,5)    

#after  passing 3 and 5 the return value i.e. sum will be stored in return_value..

print("SUM outside function is::", return_value)

# if we observe inside function sum is local variable has calculated actual value .  
#when we called the function outside the same value of sum is stored in return_value
 

8. If a function does not have a return statement, what is the return value of a call to that function?

Answer is NONE.  

def my_fun(a,b):
    sum = a+b # here a=3 b=5
    print("SUM Inside function is::",sum) 
    # Here it prints 8

return_value = my_fun(3,5)    #after  passing 3 and 5 
print("SUM outside function is::", return_value)  # it prints NOne

# if we observe inside function sum is local variable has calculated actual value .  
#when we called the function outside the same value of sum is not stored in return_value. Because no return in function

9. How do you make a function variable refer to the global variable?

Using global keyword..
def my_fun(a,b):
    global sum
    sum = a+b # here a=3 b=5
    print("SUM Inside function is::",sum)
    #output is 8

my_fun(3,5)   
print("SUM outside function is::", sum)
#output is 8

10. What is the data type of None?
None data type used to if there is no value or returns null value..

def fun(f_name):

  if(f_name == None):
    print("first name missing")
  else:
    print("Name of the prerson is::", f_name) 

fun(None)

11. What does the sentence import are all your pets named eric do?

From pets import eric 

12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

If bacon is defined in spam module as 

Import spam
def bacon():
	print("This is bacon from spam module")

then we can call bacon()

import spam
spam.bacon()

13. What can you do to save a programme from crashing if it encounters an error?

We use try and exception .. instead of loosing out of our control we use try and exception, so except catches the error value.

14. What is the purpose of the try clause? What is the purpose of the except clause?

Try clause used execute a statement or expression, whenever there s an error occurs we use exception clause to handle that error to protect system from crash. All the errors in try clause are handled by exception by certain predefined errors like ValueError etc..

try:
  my_input  = input("Enter the Integer Number::::")
  
  my_input == int(my_input)
  print("Entered Value is integer::",my_input)
  
except ValueError:

  print("Not a valid Integer")

print(my_input)
