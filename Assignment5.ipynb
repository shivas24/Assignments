# %%
1. What does an empty dictionary's code look like?
	My_dict={}

2. What is the value of a dictionary value with the key 'foo' and the value 42?
	My_dict={‘foo’:42}
Foo is key
42 is  keyvalue

3. What is the most significant distinction between a dictionary and a list?
	Dictionaries cant contain duplicates values where as lists
	
4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
	Spam={‘bar’:100}
We are accessing spam[‘foo’] it will throw error because there is no such key ‘foo’

5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
spam={'x':'cat'}
print('cat' in spam)      # Returns False because it checks in key only
print('cat' in spam.keys())# Returns False because it check in key only by default

spam={'cat':'x'}
print('cat' in spam)   # Returns True
print('cat' in spam.keys()) # Returns True

#By default it checks key only

spam={'x':'cat'}

spam['cat'] ='dog'
print(spam)   #Output {'x': 'cat', 'cat': 'dog'}

spam1={'cat':'x'}
spam1['cat'] ='fox'
print(spam1)#Output  {'cat': 'fox'}

6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
#By default it checks key only

spam={'x':'cat'}
print('cat' in spam)     #By default it checks key only
print('cat' in spam.values()) # it checks key values only

spam={'cat':'x'}
print('cat' in spam)   # By defaultit checks keys only
print('cat' in spam.values())  # Here it checks key value
	

7. What is a shortcut for the following code?
if 'color' not in spam:
spam['color'] = 'black'

spam={'cat':'x'}
spam.update({'color':'Black'})
print(spam)

spam1={'cat':'x','color':'white'}
spam1.update({'color':'Black'})
print(spam1)

8. How do you "pretty print" dictionary values using which module and function?
pprint() function from pprint module
from pprint import pprint
my_dictin={'Name':'Shivaprrasad','Age':40, 
           'Address':{
              'Street':'dwarakanagar','city':'Visakhapatnam','state':'Andhrapradesh'}}
pprint(my_dictin)

#Output
{'Address': {'Street': 'dwarakanagar',
             'city': 'Visakhapatnam',
             'state': 'Andhrapradesh'},
 'Age': 40,
 'Name': 'Shivaprrasad'}
